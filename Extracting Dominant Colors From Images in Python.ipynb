# %%
from colorthief import ColorThief
import matplotlib.pyplot as plt
ct = ColorThief('T-shirt.png')
print(ct.get_color(quality=1))
# Out:
# (37, 44, 46)

# %%
dominant_color = ct.get_color(quality=1)
plt.imshow([[dominant_color]])
plt.show()

# %%
from colorthief import ColorThief
import matplotlib.pyplot as plt
ct = ColorThief('T-shirt1.jpg')
dominant_color = ct.get_color(quality=1)
plt.imshow([[dominant_color]])
plt.show()

# %%
palette = ct.get_palette(color_count=5)
plt.imshow([[palette[i] for i in range(5)]])
plt.show()

# %%
ct = ColorThief('T-shirt.png')
palette = ct.get_palette(color_count=5)
plt.imshow([[palette[i] for i in range(5)]])
plt.show()

# %%
import colorsys
for color in palette:
    print(color)
    print(f"#{color[0]:02x}{color[1]:02x}{color[2]:02x}")
    print(colorsys.rgb_to_hsv(*color))
    print(colorsys.rgb_to_hls(*color))
# Out:
# (37, 44, 46)
# #252c2e
# (0.5370370370370371, 0.1956521739130435, 46)
# (0.5370370370370371, 41.5, -0.1111111111111111)
# (213, 218, 219)
# #d5dadb
# (0.5277777777777778, 0.0273972602739726, 219)
# (0.5277777777777778, 216.0, -0.013953488372093023)
# (103, 179, 200)
# #67b3c8
# (0.5360824742268041, 0.485, 200)
# (0.5360824742268041, 151.5, -0.3222591362126246)
# (60, 137, 163)
# #3c89a3
# (0.5420711974110032, 0.6319018404907976, 163)
# (0.5420711974110032, 111.5, -0.4660633484162896)
# (156, 156, 153)
# #9c9c99
# (0.16666666666666666, 0.019230769230769232, 156)
# (0.16666666666666666, 154.5, -0.009771986970684038)
